# %% [markdown]
# #### Import EegTF functions.
# Fixme: Take note of library versions.

# %%
import EegTF

# %% [markdown]
# Input path of EEG .mat file

# %%
fileName = '/Users/isaacmenchaca/Desktop/reanlysis/EEG_DATA_SQUEEZE_Epoch_matfiles/P10_S2_filter_ref1_mas epoch.mat'

# %% [markdown]
# # stft4EEGChannel

# %% [markdown]
# ### Note:
# Possible scalings are 'density' (has units of V * * 2 / Hz) and 'spectrum' (has units of V * * 2).

# %% [markdown]
# #### Functionality test 1

# %%
f, t, Zxx = EegTF.stft4EegChannel(fileName = fileName, channel = 'Fz', timeStep = 10, 
                startTime = -1500, endTime = 3500, windowSize = 1000, 
                desiredStartTime = -1000, desiredEndTime = 3000,
                trial_epoch = 6,
                frequencyStop = 40, 
                windowTaper = 'hann')
# Out:
# EEG data shape (channels, data points, epochs): (32, 11500, 7)
# Time: -2000 to 20998
# Sampling rate: 500.0
# Num. of Trial Epochs: 7
# Num. of Channels: 32
# Channel selected: Fz

# %% [markdown]
# #### Functionality test 2

# %%
f, t, Zxx = EegTF.stft4EegChannel(fileName = fileName, channel = 'Fz', timeStep = 10, 
                startTime = -1500, endTime = 3500, windowSize = 1000, 
                desiredStartTime = -1000, desiredEndTime = 3000,
                trial_epoch = 1,
                frequencyStop = 40, 
                windowTaper = 'hann', scaling = 'density', plot_data= 'All_cb')
# Out:
# EEG data shape (channels, data points, epochs): (32, 11500, 7)
# Time: -2000 to 20998
# Sampling rate: 500.0
# Num. of Trial Epochs: 7
# Num. of Channels: 32
# Channel selected: Fz

# %% [markdown]
# #### Functionality test 3

# %%
f, t, Zxx = EegTF.stft4EegChannel(fileName = fileName, channel = 'Fz', timeStep = 10, 
                startTime = -1500, endTime = 3500, windowSize = 1000, 
                trial_epoch = 1,
                frequencyStop = 40, 
                windowTaper = 'hann', plot_data= 'tf')
# Out:
# EEG data shape (channels, data points, epochs): (32, 11500, 7)
# Time: -2000 to 20998
# Sampling rate: 500.0
# Num. of Trial Epochs: 7
# Num. of Channels: 32
# Channel selected: Fz

# %% [markdown]
# #### Functionality test 4

# %%
f, t, Zxx = EegTF.stft4EegChannel(fileName = fileName, channel = 'Fz', timeStep = 10, 
                startTime = -1500, endTime = 3500, windowSize = 1000, 
                desiredStartTime = -1000, desiredEndTime = 3000,
                trial_epoch = 1,
                frequencyStop = 40, 
                windowTaper = 'hann', plot_data = 'tf_3d', scaling = 'density')
# Out:
# EEG data shape (channels, data points, epochs): (32, 11500, 7)
# Time: -2000 to 20998
# Sampling rate: 500.0
# Num. of Trial Epochs: 7
# Num. of Channels: 32
# Channel selected: Fz

# %% [markdown]
# #### Functionality test 5

# %%
f, t, Zxx = EegTF.stft4EegChannel(fileName = fileName, channel = 'Fz', timeStep = 10, 
                startTime = -1500, endTime = 3500, windowSize = 1000, 
                desiredStartTime = -1000, desiredEndTime = 3000,
                trial_epoch = 4,
                frequencyStop = 40, log_power = False,
                windowTaper = 'hann', plot_data = 'All', scaling = 'density')
# Out:
# EEG data shape (channels, data points, epochs): (32, 11500, 7)
# Time: -2000 to 20998
# Sampling rate: 500.0
# Num. of Trial Epochs: 7
# Num. of Channels: 32
# Channel selected: Fz

# %% [markdown]
# # cwtMorl4EEGChannel

# %% [markdown]
# #### Functionality test 1

# %%
f, t, Zxx = EegTF.cwtMorl4EEGChannel(fileName = fileName, channel = 'Fz', 
                           startTime = -1000, endTime = 3000, trial_epoch = 6, 
                           frequencyStop = 40, plot_data = 'All',
                           w = 3.)
# Out:
# EEG data shape (channels, data points, epochs): (32, 11500, 7)
# Time: -2000 to 20998
# Sampling rate: 500.0
# Num. of Trial Epochs: 7
# Num. of Channels: 32
# Channel selected: Fz

# %% [markdown]
# #### Functionality test 2

# %%
f, t, Zxx = EegTF.cwtMorl4EEGChannel(fileName = fileName, channel = 'Fz', 
                         startTime = -1000, endTime = 3000, trial_epoch = 6, 
                         frequencyStop = 40, plot_data = 'All_cb',
                         w = 3.)
# Out:
# EEG data shape (channels, data points, epochs): (32, 11500, 7)
# Time: -2000 to 20998
# Sampling rate: 500.0
# Num. of Trial Epochs: 7
# Num. of Channels: 32
# Channel selected: Fz

# %% [markdown]
# #### Functionality test 3

# %%
f, t, Zxx = EegTF.cwtMorl4EEGChannel(fileName = fileName, channel = 'Fz', 
                           startTime = -1000, endTime = 3000, trial_epoch = 1, 
                           frequencyStop = 40, plot_data = 'tf',
                           w = 4.)
# Out:
# EEG data shape (channels, data points, epochs): (32, 11500, 7)
# Time: -2000 to 20998
# Sampling rate: 500.0
# Num. of Trial Epochs: 7
# Num. of Channels: 32
# Channel selected: Fz

# %% [markdown]
# #### Functionality test 4

# %%
f, t, Zxx = EegTF.cwtMorl4EEGChannel(fileName = fileName, channel = 'Fz', 
                           startTime = -1000, endTime = 3000, trial_epoch = 1, 
                           frequencyStop = 40, plot_data = 'tf_3d',
                           w = 4.)
# Out:
# EEG data shape (channels, data points, epochs): (32, 11500, 7)
# Time: -2000 to 20998
# Sampling rate: 500.0
# Num. of Trial Epochs: 7
# Num. of Channels: 32
# Channel selected: Fz

# %% [markdown]
# #### Functionality test 5

# %%
f, t, Zxx = EegTF.cwtMorl4EEGChannel(fileName = fileName, channel = 'Fz', 
                           startTime = -1000, endTime = 3000, trial_epoch = 4, 
                           frequencyStop = 40, log_power = False,
                           plot_data = 'All',
                           w = 4.)
# Out:
# EEG data shape (channels, data points, epochs): (32, 11500, 7)
# Time: -2000 to 20998
# Sampling rate: 500.0
# Num. of Trial Epochs: 7
# Num. of Channels: 32
# Channel selected: Fz
